# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %%
from IPython.display import Image, display
from typing import Literal

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage
from langchain_core.runnables import RunnableConfig

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph import MessagesState

# LLM
model = ChatOpenAI(model="gpt-4o", temperature=0) 

# State 
class State(MessagesState):
    summary: str
    turn_count: int

# Define the logic to call the model
def call_model(state: State, config: RunnableConfig):
    
    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:
        
        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]
    
    else:
        messages = state["messages"]
    
    response = model.invoke(messages, config)
    return {"messages": response, "turn_count": state.get("turn_count", 0) + 1}

def summarize_conversation(state: State):
    
    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt 
    if summary:
        
        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
        
    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)
    
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# Determine whether to end or summarize the conversation
def should_continue(state: State)-> Literal ["summarize_conversation",END]:
    
    """Return the next node to execute."""
    
    messages = state["messages"]
    
    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"
    
    # Otherwise we can just end
    return END

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    print(chunk)
# Out:
# {'conversation': {'messages': AIMessage(content='Hello Lance! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 11, 'total_tokens': 21, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgIGVR39PiX4QZofzi8a57YHsNwNj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--18a2581b-4172-4806-9c2e-95ef39f3dcbe-0', usage_metadata={'input_tokens': 11, 'output_tokens': 10, 'total_tokens': 21, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'turn_count': 1}}

# %%
# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    chunk['conversation']["messages"].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hi Lance! How's it going? What can I do for you today?

# %%
# Start conversation, again
config = {"configurable": {"thread_id": "2"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Lance")
for event in graph.stream({"messages": [input_message]}, config, stream_mode="values"):
    for m in event['messages']:
        m.pretty_print()
    print("---"*25)
# Out:
# ================================ Human Message =================================
#
# hi! I'm Lance
# ---------------------------------------------------------------------------
# ================================ Human Message =================================
#
# hi! I'm Lance
# ================================== Ai Message ==================================
#
# Hello Lance! How can I assist you today?
# ---------------------------------------------------------------------------

# %%
config = {"configurable": {"thread_id": "3"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    print(f"Node: {event['metadata'].get('langgraph_node','')}. Type: {event['event']}. Name: {event['name']}")
# Out:
# Node: . Type: on_chain_start. Name: LangGraph
# Node: conversation. Type: on_chain_start. Name: conversation
# Node: conversation. Type: on_chat_model_start. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_end. Name: ChatOpenAI
# Node: conversation. Type: on_chain_start. Name: should_continue
# Node: conversation. Type: on_chain_end. Name: should_continue
# Node: conversation. Type: on_chain_stream. Name: conversation
# Node: conversation. Type: on_chain_end. Name: conversation
# Node: . Type: on_chain_stream. Name: LangGraph
# Node: . Type: on_chain_end. Name: LangGraph

# %%
node_to_stream = 'conversation'
config = {"configurable": {"thread_id": "4"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        print(event["data"])
# Out:
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' professional', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' American', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' football', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' based', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Bay', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Area', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' They', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' compete', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' League', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='NFL', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' as', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' member', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' club', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' league', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content="'s", additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Conference', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='N', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='FC', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' West', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' division', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' was', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' founded', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='194', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='6', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' as', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' charter', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' member', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' All', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='-Amer', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='ica', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Conference', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='AA', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='FC', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' joined', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' NFL', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='194', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' when', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' leagues', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' merged', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='###', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Key', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Points', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=':\n\n', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='Team', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Name', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Colors', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' named', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' after', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' prospect', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='ors', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' who', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' arrived', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Northern', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' California', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' during', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='184', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Gold', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Rush', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=" team's", additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' colors', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' red', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' gold', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' white', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='St', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='adium', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' play', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' home', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' games', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' at', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Levi', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content="'s", additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Stadium', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Santa', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Clara', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' California', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' which', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' they', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' moved', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='201', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Before', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' that', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' they', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' played', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' at', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Cand', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='lestick', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Park', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='Champ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='ionship', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Success', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' one', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' most', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' successful', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' teams', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' NFL', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' history', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' They', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' won', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' five', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Super', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' championships', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='198', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='198', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='198', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='8', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='198', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='199', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' seasons', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' appeared', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Super', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' multiple', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' times', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' They', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' also', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' won', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' numerous', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' division', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' titles', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' conference', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' championships', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='Not', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='able', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Figures', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' has', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' had', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' several', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Hall', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Fame', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' players', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' including', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Joe', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Montana', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Jerry', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Rice', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Steve', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Young', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Ronnie', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' L', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='ott', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' many', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' others', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Bill', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Walsh', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' legendary', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' head', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' coach', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' credited', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' developing', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' West', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Coast', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' offense', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' which', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' became', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' staple', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=" team's", additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' success', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='198', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='199', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='R', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='ival', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='ries', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' notable', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' rival', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='ries', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' several', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' teams', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' including', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Dallas', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Cowboys', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Los', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Angeles', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Rams', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Seattle', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Seahawks', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' These', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# ...
# {'chunk': AIMessageChunk(content=' reached', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Super', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='201', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' season', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' but', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' lost', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Kansas', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' City', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Chiefs', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' has', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' been', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' competitive', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' NFC', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' West', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' often', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' cont', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='ending', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' playoff', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' spots', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='Ownership', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Management', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' owned', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' by', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' York', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' family', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' Jed', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' York', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' serving', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' as', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' CEO', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' general', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' manager', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' head', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' coach', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' positions', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' seen', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' changes', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' over', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' years', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' focus', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' building', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' competitive', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' through', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' both', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' draft', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' free', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' agency', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' passionate', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' fan', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' base', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' rich', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' history', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' making', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' them', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' one', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' iconic', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' franchises', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content=' NFL', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'service_tier': 'default'}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944')}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--46c53a89-2667-4206-b1ac-3156a9d7d944', usage_metadata={'input_tokens': 16, 'output_tokens': 504, 'total_tokens': 520, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})}

# %%
config = {"configurable": {"thread_id": "5"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        data = event["data"]
        print(data["chunk"].content, end="|")
# Out:
# |The| San| Francisco| |49|ers| are| a| professional| American| football| team| based| in| the| San| Francisco| Bay| Area|.| They| compete| in| the| National| Football| League| (|NFL|)| as| a| member| club| of| the| league|'s| National| Football| Conference| (|N|FC|)| West| division|.| The| team| was| founded| in| |194|6| as| a| charter| member| of| the| All|-Amer|ica| Football| Conference| (|AA|FC|)| and| joined| the| NFL| in| |194|9| when| the| leagues| merged|.
#
# |###| Key| Points|:
#
# |-| **|St|adium|**|:| The| |49|ers| play| their| home| games| at| Levi|'s| Stadium| in| Santa| Clara|,| California|,| which| they| moved| to| in| |201|4|.| Before| that|,| they| played| at| Cand|lestick| Park| in| San| Francisco|.
#
# |-| **|Team| Colors| and| Masc|ot|**|:| The| team's| colors| are| red|,| gold|,| and| white|,| and| their| mascot| is| S|ourd|ough| Sam|.
#
# |-| **|Champ|ionship|s|**|:| The| |49|ers| have| won| five| Super| Bowl| titles| (|X|VI|,| XIX|,| XX|III|,| XX|IV|,| and| XX|IX|),| with| their| most| successful| period| being| the| |198|0|s| and| early| |199|0|s|.| They| have| also| won| numerous| division| titles| and| conference| championships|.
#
# |-| **|Not|able| Players|**|:| The| team| has| had| several| Hall| of| Fame| players|,| including| Joe| Montana|,| Jerry| Rice|,| Steve| Young|,| Ronnie| L|ott|,| and| Charles| Haley|.| These| players| were| instrumental| in| the| team's| success| during| their| championship| years|.
#
# |-| **|Co|aching| and| Management|**|:| The| |49|ers| have| had| several| notable| head| coaches|,| including| Bill| Walsh|,| who| is| credited| with| popular|izing| the| West| Coast| offense|,| and| George| Se|if|ert|.| As| of| my| last| update|,| Kyle| Shan|ahan| is| the| head| coach|,| and| John| Lynch| is| the| general| manager|.
#
# |-| **|R|ival|ries|**|:| The| |49|ers| have| intense| rival|ries| with| several| teams|,| most| notably| the| Dallas| Cowboys|,| Los| Angeles| Rams|,| and| Seattle| Seahawks|.| These| rival|ries| have| been| fueled| by| numerous| high|-st|akes| games| and| playoff| match|ups|.
#
# |-| **|Recent| Performance|**|:| In| recent| years|,| the| |49|ers| have| experienced| both| ups| and| downs|.| They| reached| the| Super| Bowl| in| the| |201|9| season| but| lost| to| the| Kansas| City| Chiefs|.| The| team| has| been| competitive| in| the| NFC| West|,| often| cont|ending| for| playoff| spots|.
#
# |The| |49|ers| are| known| for| their| rich| history|,| passionate| fan| base|,| and| significant| contributions| to| the| NFL|'s| development| and| popularity|.|||
